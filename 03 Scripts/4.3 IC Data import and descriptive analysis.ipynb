# %% [markdown]
#  01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 02. Define path

# %%
path = r'/Users/shikongo/Instacart Basket Analysis/'

# %%
path
# Out:
# '/Users/shikongo/Instacart Basket Analysis/'

# %% [markdown]
# 03. Turn folder path into string

# %%
df = pd.read_csv(r'/Users/shikongo/Instacart Basket Analysis/02 Data/Original Data/orders.csv', index_col = False)

# %% [markdown]
# 04. Code - import the “orders.csv” data set into notebook using the os library and the vars_list shortcut, omitting the “eval_set” column in your final dataframe.04.

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
vars_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %% [markdown]
# 05. Print the first 5 rows of the dataframe.

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# 06. Import the “products.csv” file into Jupyter as df_prods
# (as opposed to df, which is what your “orders.csv” file is named in Jupyter).
# You can use the path variable you created in step 4 to import “products.csv” with the os library.

# %%
df = pd.read_csv(r'/Users/shikongo/Instacart Basket Analysis/02 Data/Original Data/products.csv', index_col = False)

# %% [markdown]
# 07. Print the first 20 rows of the df_prods dataframe.

# %%
df.head(20)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2168274        2             1          2                 11
# 12   1501582        2             2          5                 10
# ...

# %% [markdown]
# 08. Print the last 35 rows of the df_prods dataframe

# %%
df.head(35)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %% [markdown]
# 09. Print the names of the columns in the df_prods dataframe

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %% [markdown]
# 10. Print the number of rows and columns in the df_prods dataframe.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49693 non-null  int64
#  1   product_name   49677 non-null  object
#  2   aisle_id       49693 non-null  int64
#  3   department_id  49693 non-null  int64
#  4   prices         49693 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# What’s the maximum value of the “aisle_id” column?
# = 134

# %% [markdown]
# What’s the data type of the “department_id” column?
# = int64
